# %%
import pandas as pd

# %%
file_path = '/Users/gabrielacorrea/Music/Proyecto 3/cauca_colegios.csv'
df = pd.read_csv(file_path)
df
# Out:
#         PERIODO ESTU_TIPODOCUMENTO  ESTU_CONSECUTIVO COLE_AREA_UBICACION  \
# 0         20132                 TI  SB11201320464198              URBANO
# 1         20194                 TI  SB11201940014773               RURAL
# 2         20194                 TI  SB11201940014773               RURAL
# 3         20111                 TI  SB11201110071456              URBANO
# 4         20172                 TI  SB11201720406614              URBANO
# ...         ...                ...               ...                 ...
# 174163    20221                 TI    AC202210017124              URBANO
# 174164    20221                 TI    AC202210020447              URBANO
# 174165    20221                 TI    AC202210006881              URBANO
# 174166    20221                 TI    AC202210008806              URBANO
# 174167    20221                 CC    AC202210069828              URBANO
#
#        COLE_BILINGUE COLE_CALENDARIO      COLE_CARACTER  \
# ...

# %%
df['PERIODO'].unique()
# Out:
# array([20132, 20194, 20111, 20172, 20122, 20112, 20162, 20102, 20152,
#        20142, 20201, 20131, 20151, 20101, 20161, 20221, 20121, 20171,
#        20211, 20191, 20141, 20224, 20181])

# %%
# Asegúrate de que la columna 'estu_fechanacimiento' esté en formato datetime
df['ESTU_FECHANACIMIENTO'] = pd.to_datetime(df['ESTU_FECHANACIMIENTO'], errors='coerce')

# Calcular la frecuencia de las fechas
frecuencia_fechas = df['ESTU_FECHANACIMIENTO'].value_counts()

# Mostrar la frecuencia
print(frecuencia_fechas)
# Out:
# ESTU_FECHANACIMIENTO
# 1999-01-01    112
# 2000-01-01     73
# 2005-09-17     69
# 1996-02-02     68
# 2002-12-17     66
#              ...
# 1987-09-24      1
# 1965-04-14      1
# 1965-10-04      1
# 1977-05-23      1
# 1982-06-23      1
# Name: count, Length: 10355, dtype: int64
# /var/folders/mf/7jscsv1s54g2hm1612ll7b1r0000gn/T/ipykernel_1530/1069631522.py:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['ESTU_FECHANACIMIENTO'] = pd.to_datetime(df['ESTU_FECHANACIMIENTO'], errors='coerce')

# %%
df = df.drop(columns=['ESTU_TIPODOCUMENTO','COLE_COD_DANE_ESTABLECIMIENTO','COLE_COD_DANE_SEDE',
                      'COLE_COD_DEPTO_UBICACION','COLE_COD_MCPIO_UBICACION', 'COLE_CODIGO_ICFES', 'COLE_NOMBRE_ESTABLECIMIENTO',
                      'COLE_SEDE_PRINCIPAL','ESTU_COD_DEPTO_PRESENTACION','ESTU_COD_MCPIO_PRESENTACION','ESTU_COD_RESIDE_DEPTO',	
                      'ESTU_COD_RESIDE_MCPIO','ESTU_ESTUDIANTE','ESTU_FECHANACIMIENTO'])

# %%
df.columns
# Out:
# Index(['PERIODO', 'ESTU_CONSECUTIVO', 'COLE_AREA_UBICACION', 'COLE_BILINGUE',
#        'COLE_CALENDARIO', 'COLE_CARACTER', 'COLE_DEPTO_UBICACION',
#        'COLE_GENERO', 'COLE_JORNADA', 'COLE_MCPIO_UBICACION',
#        'COLE_NATURALEZA', 'COLE_NOMBRE_SEDE', 'ESTU_DEPTO_PRESENTACION',
#        'ESTU_DEPTO_RESIDE', 'ESTU_ESTADOINVESTIGACION', 'ESTU_GENERO',
#        'ESTU_MCPIO_PRESENTACION', 'ESTU_MCPIO_RESIDE', 'ESTU_NACIONALIDAD',
#        'ESTU_PAIS_RESIDE', 'ESTU_PRIVADO_LIBERTAD', 'FAMI_CUARTOSHOGAR',
#        'FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE', 'FAMI_ESTRATOVIVIENDA',
#        'FAMI_PERSONASHOGAR', 'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENEINTERNET', 'FAMI_TIENELAVADORA', 'DESEMP_INGLES',
#        'PUNT_INGLES', 'PUNT_MATEMATICAS', 'PUNT_SOCIALES_CIUDADANAS',
#        'PUNT_C_NATURALES', 'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL'],
#       dtype='object')

# %%
# Obtener los nombres de las columnas de tipo 'object'
object_columns = df.select_dtypes(include='object').columns
print("Columnas de tipo 'object':", object_columns)

# Obtener los nombres de las columnas de tipo 'float64'
float_columns = df.select_dtypes(include='float64').columns
print("Columnas de tipo 'float64':", float_columns)

# Obtener los nombres de las columnas de tipo 'int64'
int_columns = df.select_dtypes(include='int64').columns
print("Columnas de tipo 'int64':", int_columns)
# Out:
# Columnas de tipo 'object': Index(['ESTU_CONSECUTIVO', 'COLE_AREA_UBICACION', 'COLE_BILINGUE',
#        'COLE_CALENDARIO', 'COLE_CARACTER', 'COLE_DEPTO_UBICACION',
#        'COLE_GENERO', 'COLE_JORNADA', 'COLE_MCPIO_UBICACION',
#        'COLE_NATURALEZA', 'COLE_NOMBRE_SEDE', 'ESTU_DEPTO_PRESENTACION',
#        'ESTU_DEPTO_RESIDE', 'ESTU_ESTADOINVESTIGACION', 'ESTU_GENERO',
#        'ESTU_MCPIO_PRESENTACION', 'ESTU_MCPIO_RESIDE', 'ESTU_NACIONALIDAD',
#        'ESTU_PAIS_RESIDE', 'ESTU_PRIVADO_LIBERTAD', 'FAMI_CUARTOSHOGAR',
#        'FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE', 'FAMI_ESTRATOVIVIENDA',
#        'FAMI_PERSONASHOGAR', 'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENEINTERNET', 'FAMI_TIENELAVADORA', 'DESEMP_INGLES'],
#       dtype='object')
# Columnas de tipo 'float64': Index(['PUNT_INGLES', 'PUNT_MATEMATICAS', 'PUNT_SOCIALES_CIUDADANAS',
#        'PUNT_C_NATURALES', 'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL'],
#       dtype='object')
# ...

# %%
# Crear un diccionario de mapeo para convertir palabras a números
word_to_number = {
    "uno": 1,
    "dos": 2,
    "tres": 3,
    "cuatro": 4,
    "cinco": 5,
    "seis": 6,
    "siete": 7,
    "ocho": 8,
    "nueve": 9,
    "diez": 10
}

# Reemplazar las palabras en la columna con sus valores numéricos
df['FAMI_CUARTOSHOGAR'] = df['FAMI_CUARTOSHOGAR'].str.lower().map(word_to_number)

# Verificar si quedaron valores no mapeados
if df['FAMI_CUARTOSHOGAR'].isnull().any():
    print("Hay valores en 'fami_cuartoshogar' que no pudieron ser convertidos. Revisa los datos.")
# Out:
# Hay valores en 'fami_cuartoshogar' que no pudieron ser convertidos. Revisa los datos.

# %%
# Crear un diccionario de mapeo para convertir palabras a números
word_to_number = {
    "uno": 1,
    "dos": 2,
    "tres": 3,
    "cuatro": 4,
    "cinco": 5,
    "seis": 6,
    "siete": 7,
    "ocho": 8,
    "nueve": 9,
    "diez": 10
}

# Reemplazar las palabras en la columna con sus valores numéricos
df['FAMI_PERSONASHOGAR'] = df['FAMI_PERSONASHOGAR'].str.lower().map(word_to_number)

# Verificar si quedaron valores no mapeados
if df['FAMI_PERSONASHOGAR'].isnull().any():
    print("Hay valores en 'fami_personas hogar' que no pudieron ser convertidos. Revisa los datos.")
# Out:
# Hay valores en 'fami_personas hogar' que no pudieron ser convertidos. Revisa los datos.

# %%
print(df['FAMI_CUARTOSHOGAR'].dtypes)
print(df['FAMI_PERSONASHOGAR'].dtypes)
# Out:
# float64
# float64

# %%
df.shape
# Out:
# (174168, 37)

# %%
df.head()
# Out:
#    PERIODO  ESTU_CONSECUTIVO COLE_AREA_UBICACION COLE_BILINGUE  \
# 0    20132  SB11201320464198              URBANO             N
# 1    20194  SB11201940014773               RURAL           NaN
# 2    20194  SB11201940014773               RURAL           NaN
# 3    20111  SB11201110071456              URBANO             N
# 4    20172  SB11201720406614              URBANO             N
#
#   COLE_CALENDARIO COLE_CARACTER COLE_DEPTO_UBICACION COLE_GENERO COLE_JORNADA  \
# 0               A       TÉCNICO                CAUCA    FEMENINO       MAÑANA
# 1               A     ACADÉMICO                CAUCA       MIXTO     COMPLETA
# 2               A     ACADÉMICO                CAUCA       MIXTO     COMPLETA
# 3            OTRO     NO APLICA                CAUCA       MIXTO       MAÑANA
# 4               A     ACADÉMICO                CAUCA       MIXTO        TARDE
#
#   COLE_MCPIO_UBICACION  ... FAMI_TIENECOMPUTADOR FAMI_TIENEINTERNET  \
# ...

# %%
df.describe()
# Out:
#              PERIODO  FAMI_CUARTOSHOGAR  FAMI_PERSONASHOGAR    PUNT_INGLES  \
# count  174168.000000      167440.000000        96940.000000  172702.000000
# mean    20161.913159           2.988909            4.872313      45.240657
# std        39.125053           1.073498            1.663434      10.074459
# min     20101.000000           1.000000            2.000000      -1.000000
# 25%     20132.000000           2.000000            4.000000      39.000000
# 50%     20162.000000           3.000000            5.000000      44.000000
# 75%     20194.000000           4.000000            6.000000      50.000000
# max     20224.000000           9.000000           10.000000     102.960000
#
#        PUNT_MATEMATICAS  PUNT_SOCIALES_CIUDADANAS  PUNT_C_NATURALES  \
# count     174168.000000             118174.000000     118174.000000
# mean          46.184433                 45.659468         47.317396
# std           11.409632                 11.093824          9.958266
# ...

# %% [markdown]
# GESTIÓN DE DUPLICADOS

# %%
df['ESTU_CONSECUTIVO'].nunique()
# Out:
# 145800

# %%
duplicates = len(df[df.duplicated()])
print(f'Number of Duplicate Entries: {duplicates}')
# Out:
# Number of Duplicate Entries: 28368

# %% [markdown]
# Nos damos cuenta que hay 28368 duplicados con base a la repetición del consecutivo del estudiante

# %%
# Eliminar filas duplicadas basándose en 'ESTU_CONSECUTIVO'
df_sd = df.drop_duplicates(subset=['ESTU_CONSECUTIVO'])

print(f"El DataFrame ahora tiene {df_sd.shape[0]} filas.")
# Out:
# El DataFrame ahora tiene 145800 filas.

# %%
duplicates = len(df_sd[df_sd.duplicated()])
print(f'Number of Duplicate Entries: {duplicates}')
# Out:
# Number of Duplicate Entries: 0

# %%
types = df_sd.dtypes.value_counts()
print('Data Types and Frequency in Dataset:')
print(types)
# Out:
# Data Types and Frequency in Dataset:
# object     28
# float64     8
# int64       1
# Name: count, dtype: int64

# %% [markdown]
# GESTIÓN DE VALORES NULOS

# %%
# número de valores perdidos
missing_values = df_sd.isnull().sum().sum()
print(f'Number of Missing Values: {missing_values}')
# Out:
# Number of Missing Values: 334577

# %%
missing_data = df_sd.isnull().sum()

# Imprimir las columnas que tienen datos faltantes
print("Datos faltantes por columna:")
print(missing_data[missing_data > 0])
# Out:
# Datos faltantes por columna:
# COLE_BILINGUE               25962
# COLE_CALENDARIO                11
# COLE_CARACTER                1722
# ESTU_DEPTO_RESIDE             747
# ESTU_GENERO                    95
# ESTU_MCPIO_RESIDE             747
# FAMI_CUARTOSHOGAR            4332
# FAMI_EDUCACIONMADRE          4644
# FAMI_EDUCACIONPADRE          4666
# FAMI_ESTRATOVIVIENDA         4983
# FAMI_PERSONASHOGAR          48940
# FAMI_TIENEAUTOMOVIL          2780
# FAMI_TIENECOMPUTADOR         2949
# FAMI_TIENEINTERNET           4206
# FAMI_TIENELAVADORA           2667
# DESEMP_INGLES                 728
# PUNT_INGLES                   742
# PUNT_SOCIALES_CIUDADANAS    55914
# PUNT_C_NATURALES            55914
# PUNT_LECTURA_CRITICA        55914
# PUNT_GLOBAL                 55914
# dtype: int64

# %%
# Filtrar las filas donde hay valores faltantes en las columnas de puntajes
missing_data = df_sd[df_sd[['PUNT_INGLES', 'PUNT_SOCIALES_CIUDADANAS',
       'PUNT_C_NATURALES', 'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL']].isnull().any(axis=1)]

# Mostrar los valores de 'periodo' correspondientes a las filas con valores faltantes
missing_data_periodos = missing_data['PERIODO'].unique()

# Imprimir los años (periodos) con faltantes
print("Años con faltantes en los puntajes:")
print(missing_data_periodos)
# Out:
# Años con faltantes en los puntajes:
# [20132 20111 20122 20112 20102 20131 20101 20121 20141 20224 20211 20194
#  20201 20221]

# %%
# Filtrar el DataFrame para solo considerar las columnas de puntajes
puntaje_columns = ['PUNT_INGLES', 'PUNT_SOCIALES_CIUDADANAS',
       'PUNT_C_NATURALES', 'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL']

# Crear una nueva tabla con los valores faltantes (True indica que falta un valor)
missing_data = df[puntaje_columns].isnull()

# Agrupar por 'periodo' (año) y contar los faltantes por cada variable de puntaje
missing_by_year = missing_data.groupby(df['PERIODO']).sum()

# Mostrar la tabla con la frecuencia de faltantes por año y por variable de puntaje
print("\nFaltantes por año y por variable de puntaje:\n")
# Mejor presentación con formato de tabla
print(missing_by_year.to_string(index=True))  # Esto muestra la tabla con un formato más limpio
# Out:
# Faltantes por año y por variable de puntaje:
#
#          PUNT_INGLES  PUNT_SOCIALES_CIUDADANAS  PUNT_C_NATURALES  PUNT_LECTURA_CRITICA  PUNT_GLOBAL
# PERIODO
# 20101              0                      1114              1114                  1114         1114
# 20102              0                     11865             11865                 11865        11865
# 20111              0                      1142              1142                  1142         1142
# 20112              0                     12634             12634                 12634        12634
# 20121              0                      1123              1123                  1123         1123
# 20122              0                     12856             12856                 12856        12856
# 20131              0                       925               925                   925          925
# 20132              0                     13444             13444                 13444        13444
# ...

# %%
periodos_a_filtrar = [20101, 20102, 20111, 20112, 20121, 20122, 20131, 20132, 20141]


columnas_puntajes = ['PUNT_INGLES', 'PUNT_SOCIALES_CIUDADANAS',
       'PUNT_C_NATURALES', 'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL']

# Filtrar las filas donde el periodo está en los periodos a considerar
df_filtrado = df[df['PERIODO'].isin(periodos_a_filtrar)]

df_sin_faltantes = df_filtrado.dropna(subset=columnas_puntajes)


df_limpio = pd.concat([df[~df['PERIODO'].isin(periodos_a_filtrar)], df_sin_faltantes])


print(df_limpio)
# Out:
#         PERIODO  ESTU_CONSECUTIVO COLE_AREA_UBICACION COLE_BILINGUE  \
# 1         20194  SB11201940014773               RURAL           NaN
# 2         20194  SB11201940014773               RURAL           NaN
# 4         20172  SB11201720406614              URBANO             N
# 8         20162  SB11201620095971               RURAL           NaN
# 10        20162  SB11201620370032               RURAL             N
# ...         ...               ...                 ...           ...
# 174163    20221    AC202210017124              URBANO             N
# 174164    20221    AC202210020447              URBANO             N
# 174165    20221    AC202210006881              URBANO             N
# 174166    20221    AC202210008806              URBANO             N
# 174167    20221    AC202210069828              URBANO             N
#
#        COLE_CALENDARIO      COLE_CARACTER COLE_DEPTO_UBICACION COLE_GENERO  \
# ...

# %%
missing_values = df_limpio.isnull().sum().sum()
print(f'Number of Missing Values: {missing_values}')
# Out:
# Number of Missing Values: 146509

# %%
# Calcular los valores faltantes por columna
missing_data = df_limpio.isnull().sum()

# Filtrar solo las columnas que tienen valores faltantes
missing_data = missing_data[missing_data > 0]

# Crear un DataFrame con los datos faltantes y los tipos de columnas
missing_data_info = pd.DataFrame({
    'missing_count': missing_data,
    'data_type': df_limpio.dtypes[missing_data.index]
})

# Imprimir las columnas que tienen datos faltantes con sus tipos
print("Datos faltantes por columna y sus tipos:")
print(missing_data_info)
# Out:
# Datos faltantes por columna y sus tipos:
#                       missing_count data_type
# COLE_BILINGUE                 24487    object
# COLE_CARACTER                  2178    object
# ESTU_DEPTO_RESIDE                39    object
# ESTU_GENERO                      95    object
# ESTU_MCPIO_RESIDE                39    object
# FAMI_CUARTOSHOGAR              6094   float64
# FAMI_EDUCACIONMADRE            5827    object
# FAMI_EDUCACIONPADRE            5839    object
# FAMI_ESTRATOVIVIENDA           6957    object
# FAMI_PERSONASHOGAR            75362   float64
# FAMI_TIENEAUTOMOVIL            3725    object
# FAMI_TIENECOMPUTADOR           3457    object
# FAMI_TIENEINTERNET             5955    object
# FAMI_TIENELAVADORA             3556    object
# DESEMP_INGLES                  1433    object
# PUNT_INGLES                    1466   float64

# %%
df_limpio.shape
# Out:
# (118174, 37)

# %%
df_limpio.describe()
# Out:
#              PERIODO  FAMI_CUARTOSHOGAR  FAMI_PERSONASHOGAR    PUNT_INGLES  \
# count  118174.000000      112080.000000        42812.000000  116708.000000
# mean    20182.864657           2.948796            4.782234      46.136520
# std        28.784566           1.043360            1.628754      10.478741
# min     20142.000000           1.000000            2.000000       0.000000
# 25%     20161.000000           2.000000            4.000000      39.000000
# 50%     20181.000000           3.000000            5.000000      45.000000
# 75%     20201.000000           4.000000            6.000000      52.000000
# max     20224.000000           9.000000           10.000000     100.000000
#
#        PUNT_MATEMATICAS  PUNT_SOCIALES_CIUDADANAS  PUNT_C_NATURALES  \
# count     118174.000000             118174.000000     118174.000000
# mean          47.122946                 45.659468         47.317396
# std           11.603335                 11.093824          9.958266
# ...

# %%
df_cleaned = df_limpio.dropna()
print(df_cleaned)
# Out:
#         PERIODO  ESTU_CONSECUTIVO COLE_AREA_UBICACION COLE_BILINGUE  \
# 10        20162  SB11201620370032               RURAL             N
# 14        20162  SB11201620488530               RURAL             N
# 19        20162  SB11201620102017              URBANO             N
# 21        20152  SB11201520079743              URBANO             N
# 23        20142  SB11201420403106              URBANO             N
# ...         ...               ...                 ...           ...
# 146369    20142  SB11201420062239              URBANO             N
# 146371    20162  SB11201620133350              URBANO             N
# 146372    20142  SB11201420542155              URBANO             N
# 146373    20162  SB11201620315497              URBANO             N
# 146379    20152  SB11201520463206              URBANO             N
#
#        COLE_CALENDARIO      COLE_CARACTER COLE_DEPTO_UBICACION COLE_GENERO  \
# ...

# %%
missing_values = df_cleaned.isnull().sum().sum()
print(f'Number of Missing Values: {missing_values}')
# Out:
# Number of Missing Values: 0

# %%
df_cleaned.describe()
# Out:
#             PERIODO  FAMI_CUARTOSHOGAR  FAMI_PERSONASHOGAR   PUNT_INGLES  \
# count  34775.000000       34775.000000        34775.000000  34775.000000
# mean   20152.046154           3.001639            4.759540     48.050036
# std        8.075304           1.082772            1.627283      8.951980
# min    20142.000000           1.000000            2.000000      0.000000
# 25%    20142.000000           2.000000            4.000000     43.000000
# 50%    20152.000000           3.000000            4.000000     47.000000
# 75%    20162.000000           3.000000            6.000000     52.000000
# max    20162.000000           9.000000           10.000000    100.000000
#
#        PUNT_MATEMATICAS  PUNT_SOCIALES_CIUDADANAS  PUNT_C_NATURALES  \
# count      34775.000000              34775.000000      34775.000000
# mean          47.531589                 47.818231         48.801438
# std           10.879238                 10.290979          9.470939
# ...

# %%
df_cleaned.columns
# Out:
# Index(['PERIODO', 'ESTU_CONSECUTIVO', 'COLE_AREA_UBICACION', 'COLE_BILINGUE',
#        'COLE_CALENDARIO', 'COLE_CARACTER', 'COLE_DEPTO_UBICACION',
#        'COLE_GENERO', 'COLE_JORNADA', 'COLE_MCPIO_UBICACION',
#        'COLE_NATURALEZA', 'COLE_NOMBRE_SEDE', 'ESTU_DEPTO_PRESENTACION',
#        'ESTU_DEPTO_RESIDE', 'ESTU_ESTADOINVESTIGACION', 'ESTU_GENERO',
#        'ESTU_MCPIO_PRESENTACION', 'ESTU_MCPIO_RESIDE', 'ESTU_NACIONALIDAD',
#        'ESTU_PAIS_RESIDE', 'ESTU_PRIVADO_LIBERTAD', 'FAMI_CUARTOSHOGAR',
#        'FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE', 'FAMI_ESTRATOVIVIENDA',
#        'FAMI_PERSONASHOGAR', 'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENEINTERNET', 'FAMI_TIENELAVADORA', 'DESEMP_INGLES',
#        'PUNT_INGLES', 'PUNT_MATEMATICAS', 'PUNT_SOCIALES_CIUDADANAS',
#        'PUNT_C_NATURALES', 'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL'],
#       dtype='object')

# %%
df_cleaned['ESTU_PRIVADO_LIBERTAD'].unique()
# Out:
# array(['N'], dtype=object)

# %%
df_cleaned['ESTU_ESTADOINVESTIGACION'].unique()
# Out:
# array(['PUBLICAR', 'VALIDEZ OFICINA JURÍDICA',
#        'PRESENTE CON LECTURA TARDIA'], dtype=object)

# %% [markdown]
# Eliminamos del dataset columnas no relevantes para las preguntas de negocio, asociadas a la presentación del exámen

# %%
df_cleaned = df_cleaned.drop(columns=['ESTU_PRIVADO_LIBERTAD','ESTU_CONSECUTIVO','ESTU_ESTADOINVESTIGACION'])

# %% [markdown]
# Cada columna segun su tipo de variable

# %%
# Obtener los nombres de las columnas de tipo 'object'
object_columns = df_cleaned.select_dtypes(include='object').columns
print("Columnas de tipo 'object':", object_columns)

# Obtener los nombres de las columnas de tipo 'float64'
float_columns = df_cleaned.select_dtypes(include='float64').columns
print("Columnas de tipo 'float64':", float_columns)

# Obtener los nombres de las columnas de tipo 'int64'
int_columns = df_cleaned.select_dtypes(include='int64').columns
print("Columnas de tipo 'int64':", int_columns)
# Out:
# Columnas de tipo 'object': Index(['COLE_AREA_UBICACION', 'COLE_BILINGUE', 'COLE_CALENDARIO',
#        'COLE_CARACTER', 'COLE_DEPTO_UBICACION', 'COLE_GENERO', 'COLE_JORNADA',
#        'COLE_MCPIO_UBICACION', 'COLE_NATURALEZA', 'COLE_NOMBRE_SEDE',
#        'ESTU_DEPTO_PRESENTACION', 'ESTU_DEPTO_RESIDE', 'ESTU_GENERO',
#        'ESTU_MCPIO_PRESENTACION', 'ESTU_MCPIO_RESIDE', 'ESTU_NACIONALIDAD',
#        'ESTU_PAIS_RESIDE', 'FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE',
#        'FAMI_ESTRATOVIVIENDA', 'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENEINTERNET', 'FAMI_TIENELAVADORA', 'DESEMP_INGLES'],
#       dtype='object')
# Columnas de tipo 'float64': Index(['FAMI_CUARTOSHOGAR', 'FAMI_PERSONASHOGAR', 'PUNT_INGLES',
#        'PUNT_MATEMATICAS', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_C_NATURALES',
#        'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL'],
#       dtype='object')
# Columnas de tipo 'int64': Index(['PERIODO'], dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

puntajes = df_cleaned[['FAMI_CUARTOSHOGAR', 'FAMI_PERSONASHOGAR', 'PUNT_INGLES',
                       'PUNT_MATEMATICAS', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_C_NATURALES',
                       'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL']]


# Crear un heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(puntajes.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# Título y etiquetas
plt.title('Correlación entre variables continuas')
plt.show()

# %% [markdown]
# De acuerdo con matriz de correlación las variables de cuartos hogar y personas hogar no guardan relación alguna (correlación negativa) con puntaje global. Relación inversa débil o inexistente

# %%
df_cleaned = df_cleaned.drop(columns=['FAMI_CUARTOSHOGAR', 'FAMI_PERSONASHOGAR'])

# %% [markdown]
# Verificación valores nulos

# %%
display(df_cleaned.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34775 entries, 10 to 146379
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   PERIODO                   34775 non-null  int64
#  1   COLE_AREA_UBICACION       34775 non-null  object
#  2   COLE_BILINGUE             34775 non-null  object
#  3   COLE_CALENDARIO           34775 non-null  object
#  4   COLE_CARACTER             34775 non-null  object
#  5   COLE_DEPTO_UBICACION      34775 non-null  object
#  6   COLE_GENERO               34775 non-null  object
#  7   COLE_JORNADA              34775 non-null  object
#  8   COLE_MCPIO_UBICACION      34775 non-null  object
#  9   COLE_NATURALEZA           34775 non-null  object
#  10  COLE_NOMBRE_SEDE          34775 non-null  object
#  11  ESTU_DEPTO_PRESENTACION   34775 non-null  object
#  12  ESTU_DEPTO_RESIDE         34775 non-null  object
# ...

# %%
# Definir el umbral (90% en este caso)
threshold = 0.9

# Identificar columnas que tienen un valor predominante en al menos el 90% de las filas
constant_columns = []
for col in df_cleaned.columns:
    top_freq = df_cleaned[col].value_counts(normalize=True).iloc[0]  # Frecuencia del valor más común
    if top_freq >= threshold:
        constant_columns.append((col, top_freq))

# Mostrar resultados
if constant_columns:
    print("Columnas que tienen un único valor en el 90% o más de las filas:")
    for col, freq in constant_columns:
        print(f"Columna '{col}': {freq*100:.2f}% del mismo valor")
else:
    print("No hay columnas con un único valor predominante en el 90% o más de las filas.")
# Out:
# Columnas que tienen un único valor en el 90% o más de las filas:
# Columna 'COLE_BILINGUE': 94.06% del mismo valor
# Columna 'COLE_CALENDARIO': 95.30% del mismo valor
# Columna 'COLE_DEPTO_UBICACION': 100.00% del mismo valor
# Columna 'COLE_GENERO': 94.53% del mismo valor
# Columna 'ESTU_DEPTO_PRESENTACION': 98.15% del mismo valor
# Columna 'ESTU_DEPTO_RESIDE': 99.62% del mismo valor
# Columna 'ESTU_NACIONALIDAD': 99.98% del mismo valor
# Columna 'ESTU_PAIS_RESIDE': 99.98% del mismo valor

# %% [markdown]
# La variable departamento de ubicación del colegio es el mismo valor para todas las filas, puesto que, estamos evaluando los colegios del Cauca al ser redundante la retiramos. Así mismo, la nacionalidad y el pais de residencia se presenta el 99.99% en todos los casos igual

# %%
df_final=df_cleaned.drop(columns=['COLE_DEPTO_UBICACION'])

# %%
# Crear un box plot para cada columna numérica
numeric_columns = df_cleaned.select_dtypes(include=['float64', 'int64']).columns

plt.figure(figsize=(15, 10))
for i, col in enumerate(numeric_columns, 1):
    plt.subplot(len(numeric_columns) // 3 + 1, 3, i)
    sns.boxplot(y=df_cleaned[col])
    plt.title(f'Box plot de {col}')
    plt.tight_layout()

plt.show()

# %% [markdown]
# Observamos que la variable periodo no tiene valores extremos o fuera la media, puesto que, hace referencia al momento de presentación. Esta variable no guarda relación con el puntaje y no nos brinda información sobre la situación socioeconómica y demográfica del estudiante que pudiese influir en su rendimiento

# %%
print(df_cleaned.shape)
print(df_cleaned['COLE_NOMBRE_SEDE'].count())
# Out:
# (34775, 32)
# 34775

# %% [markdown]
# El nombre de la sede se asocia con cada fila en específico, se retira del dataset

# %%
df_final = df_cleaned.drop(columns=['COLE_NOMBRE_SEDE'])

# %% [markdown]
# Verificamos que las categorias correspondan correctamente a cada variable

# %%
# Identificar columnas categóricas
categorical_columns = df_final.select_dtypes(include=['object', 'category']).columns

# Imprimir valores únicos de cada columna categórica
for column in categorical_columns:
    print(f"Valores únicos en la columna '{column}':")
    print(df_cleaned[column].unique())
    print()
# Out:
# Valores únicos en la columna 'COLE_AREA_UBICACION':
# ['RURAL' 'URBANO']
#
# Valores únicos en la columna 'COLE_BILINGUE':
# ['N' 'S']
#
# Valores únicos en la columna 'COLE_CALENDARIO':
# ['A' 'B' 'OTRO']
#
# Valores únicos en la columna 'COLE_CARACTER':
# ['ACADÉMICO' 'TÉCNICO' 'TÉCNICO/ACADÉMICO' 'NO APLICA']
#
# Valores únicos en la columna 'COLE_DEPTO_UBICACION':
# ['CAUCA']
#
# Valores únicos en la columna 'COLE_GENERO':
# ['MIXTO' 'FEMENINO' 'MASCULINO']
#
# Valores únicos en la columna 'COLE_JORNADA':
# ['MAÑANA' 'COMPLETA' 'NOCHE' 'TARDE' 'SABATINA']
#
# Valores únicos en la columna 'COLE_MCPIO_UBICACION':
# ['BUENOS AIRES' 'ARGELIA' 'MIRANDA' 'SANTANDER DE QUILICHAO' 'LA SIERRA'
#  'TORIBIO' 'POPAYAN' 'PURACE (COCONUCO)' 'CORINTO' 'CALOTO' 'SUAREZ'
#  'MORALES' 'CALDONO' 'PATIA(EL BORDO)' 'BOLIVAR' 'INZA' 'BALBOA' 'LA VEGA'
#  'PUERTO TEJADA' 'PAEZ (BELALCAZAR)' 'PIENDAMO' 'SUCRE' 'TIMBIQUI'
#  'SAN SEBASTIAN' 'SILVIA' 'JAMBALO' 'GUACHENÉ' 'ALMAGUER' 'CAJIBIO'
# ...

# %%
df_final.columns
# Out:
# Index(['PERIODO', 'COLE_AREA_UBICACION', 'COLE_BILINGUE', 'COLE_CALENDARIO',
#        'COLE_CARACTER', 'COLE_DEPTO_UBICACION', 'COLE_GENERO', 'COLE_JORNADA',
#        'COLE_MCPIO_UBICACION', 'COLE_NATURALEZA', 'ESTU_DEPTO_PRESENTACION',
#        'ESTU_DEPTO_RESIDE', 'ESTU_GENERO', 'ESTU_MCPIO_PRESENTACION',
#        'ESTU_MCPIO_RESIDE', 'ESTU_NACIONALIDAD', 'ESTU_PAIS_RESIDE',
#        'FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE', 'FAMI_ESTRATOVIVIENDA',
#        'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET',
#        'FAMI_TIENELAVADORA', 'DESEMP_INGLES', 'PUNT_INGLES',
#        'PUNT_MATEMATICAS', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_C_NATURALES',
#        'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL'],
#       dtype='object')

# %% [markdown]
# Guardamos los datos en un DataFrame para poder realizar el EDA de los datos, lo cual nos permitirá identificar las relaciones de las variables con la variable de respuesta

# %%
# Guardar el DataFrame de datos limpios para EDA en un archivo CSV separado por ";"
df_final.to_csv('datos_limpios.csv', sep=',', index=False)

# %% [markdown]
# Estas variables se retiran conforme con lo analizado en el EDA

# %%
df_final2=df_final.drop(columns=['PERIODO', 'FAMI_TIENELAVADORA',
       'DESEMP_INGLES', 'PUNT_INGLES', 'PUNT_MATEMATICAS',
       'PUNT_SOCIALES_CIUDADANAS', 'PUNT_C_NATURALES', 'PUNT_LECTURA_CRITICA','ESTU_MCPIO_PRESENTACION',
       'ESTU_DEPTO_PRESENTACION','ESTU_PAIS_RESIDE','FAMI_TIENEAUTOMOVIL'])

# %%
df_final2.columns
# Out:
# Index(['COLE_AREA_UBICACION', 'COLE_BILINGUE', 'COLE_CALENDARIO',
#        'COLE_CARACTER', 'COLE_DEPTO_UBICACION', 'COLE_GENERO', 'COLE_JORNADA',
#        'COLE_MCPIO_UBICACION', 'COLE_NATURALEZA', 'ESTU_DEPTO_RESIDE',
#        'ESTU_GENERO', 'ESTU_MCPIO_RESIDE', 'ESTU_NACIONALIDAD',
#        'FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE', 'FAMI_ESTRATOVIVIENDA',
#        'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET', 'PUNT_GLOBAL'],
#       dtype='object')

# %% [markdown]
# Variables no signficativas en modelo de Regresión. Además de ser 99.99% igual en los registros presentados

# %%
df_final2=df_final2.drop(columns='ESTU_MCPIO_RESIDE')

# %%
df_final2=df_final2.drop(columns='ESTU_NACIONALIDAD')

# %%
df_final2.columns
# Out:
# Index(['COLE_AREA_UBICACION', 'COLE_BILINGUE', 'COLE_CALENDARIO',
#        'COLE_CARACTER', 'COLE_DEPTO_UBICACION', 'COLE_GENERO', 'COLE_JORNADA',
#        'COLE_MCPIO_UBICACION', 'COLE_NATURALEZA', 'ESTU_DEPTO_RESIDE',
#        'ESTU_GENERO', 'FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE',
#        'FAMI_ESTRATOVIVIENDA', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET',
#        'PUNT_GLOBAL'],
#       dtype='object')

# %%
# Identificar columnas categóricas
categorical_columns = df_final2.select_dtypes(include=['object', 'category']).columns

# Imprimir valores únicos de cada columna categórica
for column in categorical_columns:
    print(f"Valores únicos en la columna '{column}':")
    print(df_final2[column].unique())
    print()
# Out:
# Valores únicos en la columna 'COLE_AREA_UBICACION':
# ['RURAL' 'URBANO']
#
# Valores únicos en la columna 'COLE_BILINGUE':
# ['N' 'S']
#
# Valores únicos en la columna 'COLE_CALENDARIO':
# ['A' 'B' 'OTRO']
#
# Valores únicos en la columna 'COLE_CARACTER':
# ['ACADÉMICO' 'TÉCNICO' 'TÉCNICO/ACADÉMICO' 'NO APLICA']
#
# Valores únicos en la columna 'COLE_DEPTO_UBICACION':
# ['CAUCA']
#
# Valores únicos en la columna 'COLE_GENERO':
# ['MIXTO' 'FEMENINO' 'MASCULINO']
#
# Valores únicos en la columna 'COLE_JORNADA':
# ['MAÑANA' 'COMPLETA' 'NOCHE' 'TARDE' 'SABATINA']
#
# Valores únicos en la columna 'COLE_MCPIO_UBICACION':
# ['BUENOS AIRES' 'ARGELIA' 'MIRANDA' 'SANTANDER DE QUILICHAO' 'LA SIERRA'
#  'TORIBIO' 'POPAYAN' 'PURACE (COCONUCO)' 'CORINTO' 'CALOTO' 'SUAREZ'
#  'MORALES' 'CALDONO' 'PATIA(EL BORDO)' 'BOLIVAR' 'INZA' 'BALBOA' 'LA VEGA'
#  'PUERTO TEJADA' 'PAEZ (BELALCAZAR)' 'PIENDAMO' 'SUCRE' 'TIMBIQUI'
#  'SAN SEBASTIAN' 'SILVIA' 'JAMBALO' 'GUACHENÉ' 'ALMAGUER' 'CAJIBIO'
# ...

# %%
catcols = df_final2.select_dtypes(exclude = ['int64','float64']).columns
intcols = df_final2.select_dtypes(include = ['int64']).columns
floatcols = df_final2.select_dtypes(include = ['float64']).columns
# codificación
df_finall = pd.get_dummies(df_final2, columns = catcols,dtype=int,drop_first=True)
df_finall
# Out:
#         PUNT_GLOBAL  COLE_AREA_UBICACION_URBANO  COLE_BILINGUE_S  \
# 10            242.0                           0                0
# 14            272.0                           0                0
# 19            281.0                           1                0
# 21            307.0                           1                0
# 23            248.0                           1                0
# ...             ...                         ...              ...
# 146369        307.0                           1                0
# 146371        288.0                           1                0
# 146372        217.0                           1                0
# 146373        244.0                           1                0
# 146379        180.0                           1                0
#
#         COLE_CALENDARIO_B  COLE_CALENDARIO_OTRO  COLE_CARACTER_NO APLICA  \
# 10                      0                     0                        0
# ...

# %%
print('New Number of Features: %d'%(df_finall.shape[1]))
# Out:
# New Number of Features: 89

# %%
types = df_final.dtypes.value_counts()
print('Data Types and Frequency in Dataset:')
print(types)
# Out:
# Data Types and Frequency in Dataset:
# object     24
# float64     6
# int64       1
# Name: count, dtype: int64

# %%
# Guardar el DataFrame data_dummies en un archivo CSV separado por ";"
df_finall.to_csv('data_dummies.csv', sep=',', index=False)

# %%
# Calcular la matriz de correlación
correlation_matrix_dummies = df_finall.corr()

# Crear el heatmap
plt.figure(figsize=(15, 12))
sns.heatmap(correlation_matrix_dummies, annot=False, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Heatmap de la Matriz de Correlación de data_dummies')
plt.show()

# %%
df_finall.isna().sum()
# Out:
# PUNT_GLOBAL                       0
# COLE_AREA_UBICACION_URBANO        0
# COLE_BILINGUE_S                   0
# COLE_CALENDARIO_B                 0
# COLE_CALENDARIO_OTRO              0
#                                  ..
# FAMI_ESTRATOVIVIENDA_Estrato 4    0
# FAMI_ESTRATOVIVIENDA_Estrato 5    0
# FAMI_ESTRATOVIVIENDA_Estrato 6    0
# FAMI_TIENECOMPUTADOR_Si           0
# FAMI_TIENEINTERNET_Si             0
# Length: 89, dtype: int64

# %%
df_finall.columns
# Out:
# Index(['PUNT_GLOBAL', 'COLE_AREA_UBICACION_URBANO', 'COLE_BILINGUE_S',
#        'COLE_CALENDARIO_B', 'COLE_CALENDARIO_OTRO', 'COLE_CARACTER_NO APLICA',
#        'COLE_CARACTER_TÉCNICO', 'COLE_CARACTER_TÉCNICO/ACADÉMICO',
#        'COLE_GENERO_MASCULINO', 'COLE_GENERO_MIXTO', 'COLE_JORNADA_MAÑANA',
#        'COLE_JORNADA_NOCHE', 'COLE_JORNADA_SABATINA', 'COLE_JORNADA_TARDE',
#        'COLE_MCPIO_UBICACION_ARGELIA', 'COLE_MCPIO_UBICACION_BALBOA',
#        'COLE_MCPIO_UBICACION_BOLIVAR', 'COLE_MCPIO_UBICACION_BUENOS AIRES',
#        'COLE_MCPIO_UBICACION_CAJIBIO', 'COLE_MCPIO_UBICACION_CALDONO',
#        'COLE_MCPIO_UBICACION_CALOTO', 'COLE_MCPIO_UBICACION_CORINTO',
#        'COLE_MCPIO_UBICACION_EL TAMBO', 'COLE_MCPIO_UBICACION_FLORENCIA',
#        'COLE_MCPIO_UBICACION_GUACHENÉ', 'COLE_MCPIO_UBICACION_GUAPI',
#        'COLE_MCPIO_UBICACION_INZA', 'COLE_MCPIO_UBICACION_JAMBALO',
#        'COLE_MCPIO_UBICACION_LA SIERRA', 'COLE_MCPIO_UBICACION_LA VEGA',
# ...
