# %%
import pandas as pd
file_path = '/Users/gabrielacorrea/Music/Proyecto 3/data_dummies.csv'
df = pd.read_csv(file_path)
df
# Out:
#        PUNT_GLOBAL  COLE_AREA_UBICACION_URBANO  COLE_BILINGUE_S  \
# 0            242.0                           0                0
# 1            272.0                           0                0
# 2            281.0                           1                0
# 3            307.0                           1                0
# 4            248.0                           1                0
# ...            ...                         ...              ...
# 34770        307.0                           1                0
# 34771        288.0                           1                0
# 34772        217.0                           1                0
# 34773        244.0                           1                0
# 34774        180.0                           1                0
#
#        COLE_CALENDARIO_B  COLE_CALENDARIO_OTRO  COLE_CARACTER_NO APLICA  \
# 0                      0                     0                        0
# ...

# %%
df.columns
# Out:
# Index(['PUNT_GLOBAL', 'COLE_AREA_UBICACION_URBANO', 'COLE_BILINGUE_S',
#        'COLE_CALENDARIO_B', 'COLE_CALENDARIO_OTRO', 'COLE_CARACTER_NO APLICA',
#        'COLE_CARACTER_TÉCNICO', 'COLE_CARACTER_TÉCNICO/ACADÉMICO',
#        'COLE_GENERO_MASCULINO', 'COLE_GENERO_MIXTO', 'COLE_JORNADA_MAÑANA',
#        'COLE_JORNADA_NOCHE', 'COLE_JORNADA_SABATINA', 'COLE_JORNADA_TARDE',
#        'COLE_MCPIO_UBICACION_ARGELIA', 'COLE_MCPIO_UBICACION_BALBOA',
#        'COLE_MCPIO_UBICACION_BOLIVAR', 'COLE_MCPIO_UBICACION_BUENOS AIRES',
#        'COLE_MCPIO_UBICACION_CAJIBIO', 'COLE_MCPIO_UBICACION_CALDONO',
#        'COLE_MCPIO_UBICACION_CALOTO', 'COLE_MCPIO_UBICACION_CORINTO',
#        'COLE_MCPIO_UBICACION_EL TAMBO', 'COLE_MCPIO_UBICACION_FLORENCIA',
#        'COLE_MCPIO_UBICACION_GUACHENÉ', 'COLE_MCPIO_UBICACION_GUAPI',
#        'COLE_MCPIO_UBICACION_INZA', 'COLE_MCPIO_UBICACION_JAMBALO',
#        'COLE_MCPIO_UBICACION_LA SIERRA', 'COLE_MCPIO_UBICACION_LA VEGA',
# ...

# %%
train = df.sample(frac=0.8, random_state=100)
train
# Out:
#        PUNT_GLOBAL  COLE_AREA_UBICACION_URBANO  COLE_BILINGUE_S  \
# 10229        239.0                           1                0
# 3466         271.0                           0                0
# 3377         257.0                           0                0
# 6307         235.0                           1                0
# 14742        254.0                           1                0
# ...            ...                         ...              ...
# 18278        231.0                           1                0
# 16101        332.0                           1                0
# 11145        212.0                           1                0
# 30737        323.0                           1                0
# 6047         215.0                           0                0
#
#        COLE_CALENDARIO_B  COLE_CALENDARIO_OTRO  COLE_CARACTER_NO APLICA  \
# 10229                  0                     0                        0
# ...

# %%
test = df.drop(train.index)
test
# Out:
#        PUNT_GLOBAL  COLE_AREA_UBICACION_URBANO  COLE_BILINGUE_S  \
# 9            217.0                           1                0
# 17           202.0                           0                0
# 28           272.0                           1                0
# 39           286.0                           0                0
# 40           257.0                           1                0
# ...            ...                         ...              ...
# 34745        227.0                           1                0
# 34760        189.0                           1                1
# 34765        252.0                           1                0
# 34770        307.0                           1                0
# 34774        180.0                           1                0
#
#        COLE_CALENDARIO_B  COLE_CALENDARIO_OTRO  COLE_CARACTER_NO APLICA  \
# 9                      0                     0                        0
# ...

# %%
print(train.shape)
print(test.shape)
# Out:
# (27820, 89)
# (6955, 89)

# %%
train_X = train.copy()
test_X = test.copy()

# %%
train_y = train_X.pop('PUNT_GLOBAL')
test_y = test_X.pop('PUNT_GLOBAL')

# %%
train_X.head()
# Out:
#        COLE_AREA_UBICACION_URBANO  COLE_BILINGUE_S  COLE_CALENDARIO_B  \
# 10229                           1                0                  0
# 3466                            0                0                  0
# 3377                            0                0                  0
# 6307                            1                0                  0
# 14742                           1                0                  0
#
#        COLE_CALENDARIO_OTRO  COLE_CARACTER_NO APLICA  COLE_CARACTER_TÉCNICO  \
# 10229                     0                        0                      0
# 3466                      0                        0                      0
# 3377                      0                        0                      1
# 6307                      0                        0                      0
# 14742                     0                        0                      0
#
#        COLE_CARACTER_TÉCNICO/ACADÉMICO  COLE_GENERO_MASCULINO  \
# ...

# %%
print(train_X.describe())  # Revisa estadísticas descriptivas
# Out:
#        COLE_AREA_UBICACION_URBANO  COLE_BILINGUE_S  COLE_CALENDARIO_B  \
# count                27820.000000     27820.000000       27820.000000
# mean                     0.704853         0.058879           0.032782
# std                      0.456117         0.235401           0.178069
# min                      0.000000         0.000000           0.000000
# 25%                      0.000000         0.000000           0.000000
# 50%                      1.000000         0.000000           0.000000
# 75%                      1.000000         0.000000           0.000000
# max                      1.000000         1.000000           1.000000
#
#        COLE_CALENDARIO_OTRO  COLE_CARACTER_NO APLICA  COLE_CARACTER_TÉCNICO  \
# count          27820.000000             27820.000000           27820.000000
# mean               0.014738                 0.010388               0.389109
# std                0.120503                 0.101394               0.487557
# ...

# %%
train_y
# Out:
# 10229    239.0
# 3466     271.0
# 3377     257.0
# 6307     235.0
# 14742    254.0
#          ...
# 18278    231.0
# 16101    332.0
# 11145    212.0
# 30737    323.0
# 6047     215.0
# Name: PUNT_GLOBAL, Length: 27820, dtype: float64

# %%
test_y
# Out:
# 9        217.0
# 17       202.0
# 28       272.0
# 39       286.0
# 40       257.0
#          ...
# 34745    227.0
# 34760    189.0
# 34765    252.0
# 34770    307.0
# 34774    180.0
# Name: PUNT_GLOBAL, Length: 6955, dtype: float64

# %%
train_X.dtypes
# Out:
# COLE_AREA_UBICACION_URBANO        int64
# COLE_BILINGUE_S                   int64
# COLE_CALENDARIO_B                 int64
# COLE_CALENDARIO_OTRO              int64
# COLE_CARACTER_NO APLICA           int64
#                                   ...
# FAMI_ESTRATOVIVIENDA_Estrato 4    int64
# FAMI_ESTRATOVIVIENDA_Estrato 5    int64
# FAMI_ESTRATOVIVIENDA_Estrato 6    int64
# FAMI_TIENECOMPUTADOR_Si           int64
# FAMI_TIENEINTERNET_Si             int64
# Length: 88, dtype: object

# %%
# Obtener los nombres de las columnas
column_names = df.columns

# Mostrar los nombres de las columnas
print(column_names)
# Out:
# Index(['PUNT_GLOBAL', 'COLE_AREA_UBICACION_URBANO', 'COLE_BILINGUE_S',
#        'COLE_CALENDARIO_B', 'COLE_CALENDARIO_OTRO', 'COLE_CARACTER_NO APLICA',
#        'COLE_CARACTER_TÉCNICO', 'COLE_CARACTER_TÉCNICO/ACADÉMICO',
#        'COLE_GENERO_MASCULINO', 'COLE_GENERO_MIXTO', 'COLE_JORNADA_MAÑANA',
#        'COLE_JORNADA_NOCHE', 'COLE_JORNADA_SABATINA', 'COLE_JORNADA_TARDE',
#        'COLE_MCPIO_UBICACION_ARGELIA', 'COLE_MCPIO_UBICACION_BALBOA',
#        'COLE_MCPIO_UBICACION_BOLIVAR', 'COLE_MCPIO_UBICACION_BUENOS AIRES',
#        'COLE_MCPIO_UBICACION_CAJIBIO', 'COLE_MCPIO_UBICACION_CALDONO',
#        'COLE_MCPIO_UBICACION_CALOTO', 'COLE_MCPIO_UBICACION_CORINTO',
#        'COLE_MCPIO_UBICACION_EL TAMBO', 'COLE_MCPIO_UBICACION_FLORENCIA',
#        'COLE_MCPIO_UBICACION_GUACHENÉ', 'COLE_MCPIO_UBICACION_GUAPI',
#        'COLE_MCPIO_UBICACION_INZA', 'COLE_MCPIO_UBICACION_JAMBALO',
#        'COLE_MCPIO_UBICACION_LA SIERRA', 'COLE_MCPIO_UBICACION_LA VEGA',
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics
import numpy as np

# Separar variables predictoras (X) y la variable objetivo (y)
X= df.drop(columns='PUNT_GLOBAL')
y = df['PUNT_GLOBAL']

# Dividir los datos en conjuntos de entrenamiento y prueba
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.24, random_state=1)

# Crear y entrenar el modelo
model = LinearRegression()
model.fit(train_X, train_y)

# Realizar predicciones
y_pred = model.predict(test_X)

# %%
import numpy as np

# mean absolute error
MAE = metrics.mean_absolute_error(test_y, y_pred)

# mean squared error
MSE = metrics.mean_squared_error(test_y, y_pred)

# root mean squared error
RMSE = np.sqrt(MSE)

# %%
print("MAE: ", MAE)
print("MSE: ", MSE)
print("RMSE: ", RMSE)
# Out:
# MAE:  26.555046641272614
# MSE:  1139.2067195716904
# RMSE:  33.7521365186219

# %% [markdown]
# MODELO DE REGRESIÓN

# %%
import statsmodels.api as sm

y = df['PUNT_GLOBAL']

train_X, test_X, train_y, test_y = train_test_split(X, y, random_state=1)

# agregar constante explíticamente
train_x = sm.add_constant(train_X)

# regresión usando mínimos cuadrados ordinarios (ordinary least squares - OLS)
md = sm.OLS(train_y, train_x).fit()

# resumen de resultados
print(md.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            PUNT_GLOBAL   R-squared:                       0.377
# Model:                            OLS   Adj. R-squared:                  0.375
# Method:                 Least Squares   F-statistic:                     178.7
# Date:                Mon, 25 Nov 2024   Prob (F-statistic):               0.00
# Time:                        14:46:21   Log-Likelihood:            -1.2887e+05
# No. Observations:               26081   AIC:                         2.579e+05
# Df Residuals:                   25992   BIC:                         2.587e+05
# Df Model:                          88
# Covariance Type:            nonrobust
# ...
#                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------
# ...

# %%
# Obtén los valores p del modelo
p_values = md.pvalues

# Filtra las variables con p-value > 0.05
non_significant_vars = p_values[p_values > 0.1].index
non_significant_vars.tolist()
# Out:
# ['COLE_CARACTER_TÉCNICO/ACADÉMICO',
#  'COLE_GENERO_MASCULINO',
#  'COLE_JORNADA_MAÑANA',
#  'COLE_MCPIO_UBICACION_CALDONO',
#  'COLE_MCPIO_UBICACION_CALOTO',
#  'COLE_MCPIO_UBICACION_PATIA(EL BORDO)',
#  'COLE_MCPIO_UBICACION_SAN SEBASTIAN',
#  'COLE_MCPIO_UBICACION_SILVIA',
#  'COLE_MCPIO_UBICACION_TORIBIO',
#  'COLE_MCPIO_UBICACION_TOTORO',
#  'ESTU_DEPTO_RESIDE_CAUCA',
#  'ESTU_DEPTO_RESIDE_CHOCO',
#  'ESTU_DEPTO_RESIDE_HUILA',
#  'ESTU_DEPTO_RESIDE_NARIÑO',
#  'ESTU_DEPTO_RESIDE_VALLE',
#  'FAMI_EDUCACIONMADRE_Educación profesional incompleta',
#  'FAMI_EDUCACIONPADRE_Educación profesional incompleta',
#  'FAMI_EDUCACIONPADRE_Técnica o tecnológica completa']

# %%
# Obtén los valores p del modelo
p_values = md.pvalues

# Filtra las variables con p-value > 0.05
significant_vars = p_values[p_values < 0.1].index
significant_vars.tolist()
# Out:
# ['const',
#  'COLE_AREA_UBICACION_URBANO',
#  'COLE_BILINGUE_S',
#  'COLE_CALENDARIO_B',
#  'COLE_CALENDARIO_OTRO',
#  'COLE_CARACTER_NO APLICA',
#  'COLE_CARACTER_TÉCNICO',
#  'COLE_GENERO_MIXTO',
#  'COLE_JORNADA_NOCHE',
#  'COLE_JORNADA_SABATINA',
#  'COLE_JORNADA_TARDE',
#  'COLE_MCPIO_UBICACION_ARGELIA',
#  'COLE_MCPIO_UBICACION_BALBOA',
#  'COLE_MCPIO_UBICACION_BOLIVAR',
#  'COLE_MCPIO_UBICACION_BUENOS AIRES',
#  'COLE_MCPIO_UBICACION_CAJIBIO',
#  'COLE_MCPIO_UBICACION_CORINTO',
#  'COLE_MCPIO_UBICACION_EL TAMBO',
#  'COLE_MCPIO_UBICACION_FLORENCIA',
#  'COLE_MCPIO_UBICACION_GUACHENÉ',
#  'COLE_MCPIO_UBICACION_GUAPI',
#  'COLE_MCPIO_UBICACION_INZA',
#  'COLE_MCPIO_UBICACION_JAMBALO',
#  'COLE_MCPIO_UBICACION_LA SIERRA',
#  'COLE_MCPIO_UBICACION_LA VEGA',
#  'COLE_MCPIO_UBICACION_LOPEZ (MICAY)',
#  'COLE_MCPIO_UBICACION_MERCADERES',
#  'COLE_MCPIO_UBICACION_MIRANDA',
#  'COLE_MCPIO_UBICACION_MORALES',
#  'COLE_MCPIO_UBICACION_PADILLA',
# ...

# %% [markdown]
# MODELO RED NEURONAL DE REGRESION

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics
import numpy as np

# Separar variables predictoras (X) y la variable objetivo (y)
X= df.drop(columns='PUNT_GLOBAL')
y = df['PUNT_GLOBAL']

# Dividir los datos en conjuntos de entrenamiento y prueba
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.24, random_state=1)

# Crear y entrenar el modelo
model = LinearRegression()
model.fit(train_X, train_y)

# Realizar predicciones
y_pred = model.predict(test_X)

# %%
import sys
sys.setrecursionlimit(999)
import tensorflow as tf

# %% [markdown]
# Modelo de Prueba

# %%
import tensorflow as tf
from tensorflow.keras import regularizers
import matplotlib.pyplot as plt

# Asegúrate de que train_X es un NumPy array
train_X = train_X.to_numpy() if isinstance(train_X, pd.DataFrame) else train_X

# Crea el modelo secuencial
modelf = tf.keras.Sequential([
    tf.keras.layers.Normalization(),  # Capa de normalización de los datos
    tf.keras.layers.Dense(units=256, activation='relu', kernel_regularizer=regularizers.l2(0.005)),  # Capa densa con más unidades
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),  # Dropout ajustado a 0.3
    tf.keras.layers.Dense(units=128, activation='relu', kernel_regularizer=regularizers.l2(0.005)),  # Otra capa densa
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),  # Dropout ajustado
    tf.keras.layers.Dense(units=64, activation='relu', kernel_regularizer=regularizers.l2(0.005)),
    tf.keras.layers.Dense(units=1)  # Capa de salida para regresión
])

# Ajustar la capa de normalización a los datos
modelf.layers[0].adapt(train_X)  # Ajusta la capa de normalización a los datos de entrada

# Compilar el modelo con un optimizador ajustado y MSE como la pérdida
modelf.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),  # Optimizador Adam con tasa de aprendizaje ajustada
    loss='mean_squared_error',  # Pérdida MSE para regresión
    metrics=['mae', 'mse']  # Métricas de evaluación
)

# Entrenar el modelo
history = modelf.fit(
    train_X,
    train_y,
    epochs=30,  # Número de épocas aumentado
    validation_split=0.2,  # Usar el 20% de los datos para validación
    batch_size=256,  # Tamaño de lote ajustado
    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)],  # Early stopping
    verbose=1  # Imprimir información durante el entrenamiento
)

# Evaluar el modelo en el conjunto de prueba
test_loss, test_mae, test_mse = modelf.evaluate(test_X, test_y)
print(f"Test Loss: {test_loss}, Test MAE: {test_mae}, Test MSE: {test_mse}")

# Graficar los resultados
fig, axs = plt.subplots(3, 1, figsize=(10, 18))  # Tres subgráficas

# Pérdida (Loss)
axs[0].plot(history.history['loss'], label='Pérdida de Entrenamiento', color='blue')
axs[0].plot(history.history['val_loss'], label='Pérdida de Validación', color='orange', linestyle='--')
axs[0].set_xlabel('Época')
axs[0].set_ylabel('Pérdida')
axs[0].legend()
axs[0].set_title('Pérdida durante el entrenamiento')

# MAE (Error Absoluto Medio)
axs[1].plot(history.history['mae'], label='MAE de Entrenamiento', color='green')
axs[1].plot(history.history['val_mae'], label='MAE de Validación', color='red', linestyle='--')
axs[1].set_xlabel('Época')
axs[1].set_ylabel('MAE')
axs[1].legend()
axs[1].set_title('Error Absoluto Medio (MAE) durante el entrenamiento')

# MSE (Error Cuadrático Medio)
axs[2].plot(history.history['mse'], label='MSE de Entrenamiento', color='purple')
axs[2].plot(history.history['val_mse'], label='MSE de Validación', color='brown', linestyle='--')
axs[2].set_xlabel('Época')
axs[2].set_ylabel('MSE')
axs[2].legend()
axs[2].set_title('Error Cuadrático Medio (MSE) durante el entrenamiento')

# Mostrar las gráficas
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 58892.9297 - mae: 238.9223 - mse: 58890.9766 - val_loss: 56089.6562 - val_mae: 233.2015 - val_mse: 56087.6406
# Epoch 2/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 50724.9180 - mae: 221.4035 - mse: 50722.8555 - val_loss: 32617.6836 - val_mae: 175.9597 - val_mse: 32615.3984
# Epoch 3/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 27575.0234 - mae: 158.4767 - mse: 27572.6445 - val_loss: 10387.1475 - val_mae: 87.7319 - val_mse: 10384.4688
# Epoch 4/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 10377.0674 - mae: 86.2560 - mse: 10374.3008 - val_loss: 4034.2542 - val_mae: 42.4824 - val_mse: 4031.2422
# Epoch 5/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3564.9932 - mae: 47.9942 - mse: 3561.9241 - val_loss: 3346.6409 - val_mae: 27.7509 - val_mse: 3343.4382
# Epoch 6/30
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np  # Si no has importado numpy

# Hacer predicciones
y_pred = modelf.predict(test_X)

# MAE
mae = mean_absolute_error(test_y, y_pred)

# MSE
mse = mean_squared_error(test_y, y_pred)

# RMSE
rmse = np.sqrt(mse)


# R²
r2 = r2_score(test_y, y_pred)

# Mostrar las métricas
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared (R²): {r2}")
# Out:
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Mean Absolute Error (MAE): 26.167182174598516
# Mean Squared Error (MSE): 1133.3794501397088
# Root Mean Squared Error (RMSE): 33.66570139087717
# R-squared (R²): 0.3833259376432673

# %% [markdown]
# SEGUNDO MODELO DE PRUEBA NO MEJORA LAS MÉTRICAS

# %%
import tensorflow as tf
from tensorflow.keras import regularizers
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

# Asegúrate de que train_X es un NumPy array
train_X = train_X.to_numpy() if isinstance(train_X, pd.DataFrame) else train_X
test_X = test_X.to_numpy() if isinstance(test_X, pd.DataFrame) else test_X

# Escalar los datos utilizando StandardScaler
scaler = StandardScaler()
train_X = scaler.fit_transform(train_X)
test_X = scaler.transform(test_X)

# Crear el modelo secuencial
model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(train_X.shape[1],)),  # Capa de entrada explícita
    tf.keras.layers.Dense(units=512, activation='relu', kernel_regularizer=regularizers.l2(0.01)),  # Más unidades y regularización L2 ajustada
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.4),  # Dropout ajustado a 0.4 para mayor regularización
    tf.keras.layers.Dense(units=256, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(units=128, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(units=1)  # Capa de salida para regresión
])

# Compilar el modelo con un optimizador ajustado y MSE como la pérdida
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0003),  # Optimización más conservadora
    loss='mean_squared_error',  # Pérdida MSE para regresión
    metrics=['mae', 'mse']  # Métricas de evaluación
)



# Entrenar el modelo
history = model.fit(
    train_X,
    train_y,
    epochs=100,  # Aumento de épocas para permitir mayor aprendizaje
    validation_split=0.2,  # Usar el 20% de los datos para validación
    batch_size=256,  # Tamaño de lote ajustado
    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)],  # Early stopping más conservador
    verbose=1  # Imprimir información durante el entrenamiento
)

# Evaluar el modelo en el conjunto de prueba
test_loss, test_mae, test_mse = model.evaluate(test_X, test_y)
print(f"Test Loss: {test_loss}, Test MAE: {test_mae}, Test MSE: {test_mse}")

# Calcular R²
predictions = model.predict(test_X)
r2 = r2_score(test_y, predictions)
print(f"R-squared: {r2}")

# Graficar los resultados
fig, axs = plt.subplots(3, 1, figsize=(10, 18))  # Tres subgráficas

# Pérdida (Loss)
axs[0].plot(history.history['loss'], label='Pérdida de Entrenamiento', color='blue')
axs[0].plot(history.history['val_loss'], label='Pérdida de Validación', color='orange', linestyle='--')
axs[0].set_xlabel('Época')
axs[0].set_ylabel('Pérdida')
axs[0].legend()
axs[0].set_title('Pérdida durante el entrenamiento')

# MAE (Error Absoluto Medio)
axs[1].plot(history.history['mae'], label='MAE de Entrenamiento', color='green')
axs[1].plot(history.history['val_mae'], label='MAE de Validación', color='red', linestyle='--')
axs[1].set_xlabel('Época')
axs[1].set_ylabel('MAE')
axs[1].legend()
axs[1].set_title('Error Absoluto Medio (MAE) durante el entrenamiento')

# MSE (Error Cuadrático Medio)
axs[2].plot(history.history['mse'], label='MSE de Entrenamiento', color='purple')
axs[2].plot(history.history['val_mse'], label='MSE de Validación', color='brown', linestyle='--')
axs[2].set_xlabel('Época')
axs[2].set_ylabel('MSE')
axs[2].legend()
axs[2].set_title('Error Cuadrático Medio (MSE) durante el entrenamiento')

# Mostrar las gráficas
plt.tight_layout()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Epoch 1/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - loss: 58423.6016 - mae: 237.9062 - mse: 58416.9492 - val_loss: 55395.4141 - val_mae: 231.5830 - val_mse: 55388.6289
# Epoch 2/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 49011.7930 - mae: 216.8844 - mse: 49004.8984 - val_loss: 31606.7656 - val_mae: 162.8927 - val_mse: 31599.3848
# Epoch 3/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 20961.0605 - mae: 133.8332 - mse: 20953.4395 - val_loss: 13968.0000 - val_mae: 78.8292 - val_mse: 13959.6777
# Epoch 4/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4831.3564 - mae: 55.6263 - mse: 4822.8564 - val_loss: 9373.5332 - val_mae: 37.9463 - val_mse: 9364.6787
# Epoch 5/100
# ...

# %%
# Hacer predicciones
y_pred = model.predict(test_X)

# MAE
mae = mean_absolute_error(test_y, y_pred)

# MSE
mse = mean_squared_error(test_y, y_pred)

# RMSE
rmse = np.sqrt(mse)


# R²
r2 = r2_score(test_y, y_pred)

# Mostrar las métricas
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared (R²): {r2}")
# Out:
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Mean Absolute Error (MAE): 26.337535155182287
# Mean Squared Error (MSE): 1122.2741869373303
# Root Mean Squared Error (RMSE): 33.50036099711957
# R-squared (R²): 0.38936833392256043

# %% [markdown]
# CAPAS Y NEURONAS MODELO FINAL

# %%
# Inspecciona todas las capas de tu modelo
for i, layer in enumerate(modelf.layers):
    print(f"Capa {i}: {layer.name}, tipo: {type(layer)}")
# Out:
# Capa 0: normalization_17, tipo: <class 'keras.src.layers.preprocessing.normalization.Normalization'>
# Capa 1: dense_76, tipo: <class 'keras.src.layers.core.dense.Dense'>
# Capa 2: batch_normalization_38, tipo: <class 'keras.src.layers.normalization.batch_normalization.BatchNormalization'>
# Capa 3: dropout_36, tipo: <class 'keras.src.layers.regularization.dropout.Dropout'>
# Capa 4: dense_77, tipo: <class 'keras.src.layers.core.dense.Dense'>
# Capa 5: batch_normalization_39, tipo: <class 'keras.src.layers.normalization.batch_normalization.BatchNormalization'>
# Capa 6: dropout_37, tipo: <class 'keras.src.layers.regularization.dropout.Dropout'>
# Capa 7: dense_78, tipo: <class 'keras.src.layers.core.dense.Dense'>
# Capa 8: dense_79, tipo: <class 'keras.src.layers.core.dense.Dense'>

# %%
# Inicializa un contador para las neuronas
total_neurons = 0

# Recorre todas las capas del modelo
for i, layer in enumerate(modelf.layers):
    if hasattr(layer, 'units'):  # Verifica si la capa tiene el atributo 'units' (para capas Dense)
        total_neurons += layer.units
        print(f"Capa {i}: {layer.name}, tipo: {type(layer)}, neuronas: {layer.units}")

print(f"Total de neuronas en el modelo: {total_neurons}")
# Out:
# Capa 1: dense_76, tipo: <class 'keras.src.layers.core.dense.Dense'>, neuronas: 256
# Capa 4: dense_77, tipo: <class 'keras.src.layers.core.dense.Dense'>, neuronas: 128
# Capa 7: dense_78, tipo: <class 'keras.src.layers.core.dense.Dense'>, neuronas: 64
# Capa 8: dense_79, tipo: <class 'keras.src.layers.core.dense.Dense'>, neuronas: 1
# Total de neuronas en el modelo: 449

# %% [markdown]
# PESOS Y SESGOS DE CAPAS

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# Obtener los pesos y sesgos de las capas densas del modelo
for i, layer in enumerate(modelf.layers):
    if isinstance(layer, keras.layers.Dense):
        print(f"\n{'='*50}")
        print(f"Capa {i}: {layer.name} (Dense Layer)")
        print(f"{'='*50}")

        # Obtener los pesos y sesgos
        weights, biases = layer.get_weights()

        # Mostrar resumen de pesos
        print("\n**Pesos (Weights):**")
        print(f"- Forma: {weights.shape}")
        print(f"- Resumen:")
        print(np.array_str(weights, precision=4, suppress_small=True, max_line_width=80))

        # Mostrar resumen de sesgos
        print("\n**Sesgos (Biases):**")
        print(f"- Forma: {biases.shape}")
        print(f"- Resumen:")
        print(np.array_str(biases, precision=4, suppress_small=True, max_line_width=80))

        print(f"{'='*50}\n")
# Out:
# ...
# Capa 1: dense_40 (Dense Layer)
# ...
#
# **Pesos (Weights):**
# - Forma: (88, 256)
# - Resumen:
# [[-0.0443 -0.0149 -0.0131 ... -0.1591  0.0295  0.028 ]
#  [-0.0323 -0.135  -0.0418 ... -0.0483 -0.0596  0.0893]
#  [-0.0386 -0.1427 -0.0983 ...  0.0626  0.0081  0.0017]
#  ...
#  [ 0.0868 -0.0209  0.0576 ... -0.0496  0.0474 -0.0097]
#  [ 0.063  -0.0842  0.1068 ... -0.1296 -0.0229  0.117 ]
#  [ 0.1513  0.0609 -0.1722 ... -0.1803  0.0924  0.132 ]]
#
# **Sesgos (Biases):**
# - Forma: (256,)
# - Resumen:
# [-0.0866 -0.1055  0.1026 -0.1359  0.0235 -0.154  -0.1622 -0.061   0.1079
#   0.0104 -0.0517  0.1291  0.0387 -0.0366 -0.0422  0.0889  0.0342 -0.0326
#  -0.0052 -0.1835 -0.1381  0.0685  0.0175 -0.001  -0.0584  0.0579 -0.0257
#   0.0655  0.1595 -0.0202  0.055  -0.0695 -0.1159  0.0548  0.0403  0.0014
#  -0.0048  0.0202 -0.1071 -0.1185 -0.0344  0.072  -0.0082  0.0065  0.0434
#   0.0022 -0.105   0.0801  0.033  -0.0451  0.0305 -0.0503 -0.0727  0.1758
# ...

# %%
# Revisa la arquitectura del modelo
modelf.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization_10                │ (None, 88)             │           177 │
# │ (Normalization)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_40 (Dense)                │ (None, 256)            │        22,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 256)            │             0 │
# ...

# %%
# Obtén los pesos y sesgos de la última capa
ultima_capa = modelf.layers[-1]  # Última capa del modelo
pesos, sesgo = ultima_capa.get_weights()  # Pesos y sesgo

# %%
# Imprimir coeficientes de la regresión lineal
print("Coeficientes (Pesos):", pesos.flatten())  # Aplanar para una visualización clara
print("Intercepto (Sesgo):", sesgo[0])
# Out:
# Coeficientes (Pesos): [-0.1592983   0.35563678  0.36848614  0.620529    0.36538607  0.3251751
#  -0.15465645  0.43106785  0.36930192  0.36084652  0.49058416  0.3147977
#  -0.24603851  0.35672796  0.542038    0.4682616  -0.2885442  -0.24837294
#  -0.24725954  0.25090683  0.2704429   0.2750753   0.42636126 -0.24365693
#  -0.29379147 -0.2017169  -0.28191411  0.47114953 -0.11652408  0.46780086
#  -0.18598482  0.38985404  0.35197318  0.5399877  -0.213531    0.4411742
#   0.3801652   0.2958174   0.28040135  0.30567172  0.5791404   0.4145867
#   0.50378275  0.3366327   0.34880495  0.2883369   0.4203426   0.5025812
#   0.39035407  0.3622783  -0.13836032  0.43776068 -0.17181945  0.4724171
#  -0.12121893  0.37373912 -0.35451382  0.35275427 -0.18537514  0.31719482
#   0.35334173 -0.18264276  0.42777762 -0.2389294 ]
# Intercepto (Sesgo): 0.44370657

# %% [markdown]
# PROCESO DE SERIALIZACION Y ESCALADO

# %%
from tensorflow.keras.models import save_model, load_model

# Guardar el modelo entrenado en un archivo .keras
model.save('modelf.keras',save_format="keras")
# Out:
# WARNING:absl:The `save_format` argument is deprecated in Keras 3. We recommend removing this argument as it can be inferred from the file path. Received: save_format=keras

# %%
# Cargar el modelo en formato .keras
loaded_model = tf.keras.models.load_model("modelf.keras")

# %%
# Cargar el modelo desde el archivo .keras
loaded_model = load_model('modelf.keras')

print("Modelo cargado exitosamente.")

# Evaluar o utilizar el modelo cargado
loss, mae, mse = loaded_model.evaluate(test_X, test_y, verbose=0)
print(f"Pérdida en el conjunto de prueba: {loss}")
print(f"MAE en el conjunto de prueba: {mae}")
print(f"MSE en el conjunto de prueba: {mse}")
# Out:
# Modelo cargado exitosamente.
# Pérdida en el conjunto de prueba: 1132.624267578125
# MAE en el conjunto de prueba: 26.337528228759766
# MSE en el conjunto de prueba: 1122.274658203125

# %%
from tensorflow.keras import regularizers
from sklearn.preprocessing import StandardScaler
import pickle
import matplotlib.pyplot as plt
import tensorflow as tf

# Guardar el escalador en un archivo .pkl
with open('scaler.pkl', 'wb') as file:
    pickle.dump(scaler, file)
print("Escalador guardado como 'scaler.pkl'.")

scaler = StandardScaler()
train_X = scaler.fit_transform(train_X)
test_X = scaler.transform(test_X)

# Crear el modelo secuencial
model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(train_X.shape[1],)),  # Capa de entrada explícita
    tf.keras.layers.Dense(units=512, activation='relu', kernel_regularizer=regularizers.l2(0.01)),  # Más unidades y regularización L2 ajustada
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.4),  # Dropout ajustado a 0.4 para mayor regularización
    tf.keras.layers.Dense(units=256, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(units=128, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(units=1)  # Capa de salida para regresión
])

# Compilar el modelo con un optimizador ajustado y MSE como la pérdida
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0003),  # Optimización más conservadora
    loss='mean_squared_error',  # Pérdida MSE para regresión
    metrics=['mae', 'mse']  # Métricas de evaluación
)


# Entrenar el modelo
history = model.fit(
    train_X,
    train_y,
    epochs=100,  # Aumento de épocas para permitir mayor aprendizaje
    validation_split=0.2,  # Usar el 20% de los datos para validación
    batch_size=256,  # Tamaño de lote ajustado
    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)],  # Early stopping más conservador
    verbose=1  # Imprimir información durante el entrenamiento
)

# Evaluar el modelo en el conjunto de prueba
test_loss, test_mae, test_mse = model.evaluate(test_X, test_y)
print(f"Test Loss: {test_loss}, Test MAE: {test_mae}, Test MSE: {test_mse}")

# Calcular R²
predictions = model.predict(test_X)
r2 = r2_score(test_y, predictions)
print(f"R-squared: {r2}")
# Out:
# Escalador guardado como 'scaler.pkl'.
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Epoch 1/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 58570.9219 - mae: 238.2247 - mse: 58564.2930 - val_loss: 56241.0820 - val_mae: 233.5101 - val_mse: 56234.3398
# Epoch 2/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 49284.5977 - mae: 218.0950 - mse: 49277.7656 - val_loss: 32561.6973 - val_mae: 174.6041 - val_mse: 32554.4180
# Epoch 3/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 24431.5488 - mae: 145.5759 - mse: 24424.0605 - val_loss: 10268.5361 - val_mae: 83.8288 - val_mse: 10260.3887
# Epoch 4/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 6674.2397 - mae: 64.7997 - mse: 6665.8950 - val_loss: 4265.1689 - val_mae: 34.6696 - val_mse: 4256.3721
# Epoch 5/100
# ...

# %% [markdown]
# FUNCION QUE PREDICE EL PUNTAJE CON LAS VARIABLES EMPLEADAS

# %%
import numpy as np
import joblib
from tensorflow.keras.models import load_model

def predecir_puntaje(input_data):
    """
    Función para predecir el puntaje (PUNT_GLOBAL) a partir de los datos de entrada,
    utilizando el modelo entrenado con codificación one-hot.
    """
    # Cargar el escalador y el modelo
    scaler = joblib.load('/Users/gabrielacorrea/Music/Proyecto 3/scaler.pkl')  # Asegúrate de que 'scaler.pkl' esté en la misma ruta
    modelf = load_model('/Users/gabrielacorrea/Music/Proyecto 3/modelf.keras')  # Asegúrate de que 'modelo.keras' esté en la misma ruta
    
    # Columnas esperadas por el modelo
    expected_columns = ['COLE_AREA_UBICACION_URBANO', 'COLE_BILINGUE_S',
       'COLE_CALENDARIO_B', 'COLE_CALENDARIO_OTRO', 'COLE_CARACTER_NO APLICA',
       'COLE_CARACTER_TÉCNICO', 'COLE_CARACTER_TÉCNICO/ACADÉMICO',
       'COLE_GENERO_MASCULINO', 'COLE_GENERO_MIXTO', 'COLE_JORNADA_MAÑANA',
       'COLE_JORNADA_NOCHE', 'COLE_JORNADA_SABATINA', 'COLE_JORNADA_TARDE',
       'COLE_MCPIO_UBICACION_ARGELIA', 'COLE_MCPIO_UBICACION_BALBOA',
       'COLE_MCPIO_UBICACION_BOLIVAR', 'COLE_MCPIO_UBICACION_BUENOS AIRES',
       'COLE_MCPIO_UBICACION_CAJIBIO', 'COLE_MCPIO_UBICACION_CALDONO',
       'COLE_MCPIO_UBICACION_CALOTO', 'COLE_MCPIO_UBICACION_CORINTO',
       'COLE_MCPIO_UBICACION_EL TAMBO', 'COLE_MCPIO_UBICACION_FLORENCIA',
       'COLE_MCPIO_UBICACION_GUACHENÉ', 'COLE_MCPIO_UBICACION_GUAPI',
       'COLE_MCPIO_UBICACION_INZA', 'COLE_MCPIO_UBICACION_JAMBALO',
       'COLE_MCPIO_UBICACION_LA SIERRA', 'COLE_MCPIO_UBICACION_LA VEGA',
       'COLE_MCPIO_UBICACION_LOPEZ (MICAY)', 'COLE_MCPIO_UBICACION_MERCADERES',
       'COLE_MCPIO_UBICACION_MIRANDA', 'COLE_MCPIO_UBICACION_MORALES',
       'COLE_MCPIO_UBICACION_PADILLA',
       'COLE_MCPIO_UBICACION_PAEZ (BELALCAZAR)',
       'COLE_MCPIO_UBICACION_PATIA(EL BORDO)', 'COLE_MCPIO_UBICACION_PIENDAMO',
       'COLE_MCPIO_UBICACION_POPAYAN', 'COLE_MCPIO_UBICACION_PUERTO TEJADA',
       'COLE_MCPIO_UBICACION_PURACE (COCONUCO)', 'COLE_MCPIO_UBICACION_ROSAS',
       'COLE_MCPIO_UBICACION_SAN SEBASTIAN', 'COLE_MCPIO_UBICACION_SANTA ROSA',
       'COLE_MCPIO_UBICACION_SANTANDER DE QUILICHAO',
       'COLE_MCPIO_UBICACION_SILVIA',
       'COLE_MCPIO_UBICACION_SOTARA (PAISPAMBA)',
       'COLE_MCPIO_UBICACION_SUAREZ', 'COLE_MCPIO_UBICACION_SUCRE',
       'COLE_MCPIO_UBICACION_TIMBIO', 'COLE_MCPIO_UBICACION_TIMBIQUI',
       'COLE_MCPIO_UBICACION_TORIBIO', 'COLE_MCPIO_UBICACION_TOTORO',
       'COLE_MCPIO_UBICACION_VILLA RICA', 'COLE_NATURALEZA_OFICIAL',
       'ESTU_DEPTO_RESIDE_CAUCA', 'ESTU_DEPTO_RESIDE_CHOCO',
       'ESTU_DEPTO_RESIDE_HUILA', 'ESTU_DEPTO_RESIDE_NARIÑO',
       'ESTU_DEPTO_RESIDE_SAN ANDRES', 'ESTU_DEPTO_RESIDE_VALLE',
       'ESTU_GENERO_M', 'FAMI_EDUCACIONMADRE_Educación profesional incompleta',
       'FAMI_EDUCACIONMADRE_Ninguno', 'FAMI_EDUCACIONMADRE_No sabe',
       'FAMI_EDUCACIONMADRE_Postgrado',
       'FAMI_EDUCACIONMADRE_Primaria completa',
       'FAMI_EDUCACIONMADRE_Primaria incompleta',
       'FAMI_EDUCACIONMADRE_Secundaria (Bachillerato) completa',
       'FAMI_EDUCACIONMADRE_Secundaria (Bachillerato) incompleta',
       'FAMI_EDUCACIONMADRE_Técnica o tecnológica completa',
       'FAMI_EDUCACIONMADRE_Técnica o tecnológica incompleta',
       'FAMI_EDUCACIONPADRE_Educación profesional incompleta',
       'FAMI_EDUCACIONPADRE_Ninguno', 'FAMI_EDUCACIONPADRE_No sabe',
       'FAMI_EDUCACIONPADRE_Postgrado',
       'FAMI_EDUCACIONPADRE_Primaria completa',
       'FAMI_EDUCACIONPADRE_Primaria incompleta',
       'FAMI_EDUCACIONPADRE_Secundaria (Bachillerato) completa',
       'FAMI_EDUCACIONPADRE_Secundaria (Bachillerato) incompleta',
       'FAMI_EDUCACIONPADRE_Técnica o tecnológica completa',
       'FAMI_EDUCACIONPADRE_Técnica o tecnológica incompleta',
       'FAMI_ESTRATOVIVIENDA_Estrato 2', 'FAMI_ESTRATOVIVIENDA_Estrato 3',
       'FAMI_ESTRATOVIVIENDA_Estrato 4', 'FAMI_ESTRATOVIVIENDA_Estrato 5',
       'FAMI_ESTRATOVIVIENDA_Estrato 6', 'FAMI_TIENECOMPUTADOR_Si',
       'FAMI_TIENEINTERNET_Si']

    # Inicializar el vector con ceros
    input_vector = {col: 0 for col in expected_columns}

    # Mapear los datos de entrada a las columnas dummies
    for key, value in input_data.items():
        column_name = f"{key}_{value}"  # Nombre de la columna dummy
        if column_name in input_vector:
            input_vector[column_name] = 1

    # Convertir a numpy array
    input_array = np.array([list(input_vector.values())])

    # Escalar los datos de entrada
    input_scaled = scaler.transform(input_array)

    # Realizar la predicción
    puntaje_predicho = modelf.predict(input_scaled)

    return puntaje_predicho[0][0]

# %%
# Ejemplo de uso de la función con los valores proporcionados
input_data = {
    'COLE_AREA_UBICACION': 'URBANO',  # Reemplazar con los valores correspondientes
    'COLE_BILINGUE': 'S',
    'COLE_CALENDARIO': 'B',
    'COLE_CARACTER': 'ACADÉMICO',
    'COLE_GENERO': 'MIXTO',
    'COLE_JORNADA': 'MAÑANA',
    'COLE_MCPIO_UBICACION': 'SILVIA',
    'COLE_NATURALEZA': 'NO OFICIAL',
    'ESTU_DEPTO_RESIDE': 'CAUCA',
    'ESTU_GENERO': 'M',
    'FAMI_EDUCACIONMADRE': 'Postgrado',
    'FAMI_EDUCACIONPADRE': 'Postgrado',
    'FAMI_ESTRATOVIVIENDA': 'Estrato 5',
    'FAMI_TIENECOMPUTADOR': 'Si',
    'FAMI_TIENEINTERNET': 'Si'
}

puntaje = predecir_puntaje(input_data)
print(f"Puntaje esperado: {puntaje}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Puntaje esperado: 249.52613830566406
